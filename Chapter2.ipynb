# %% [markdown]
# <a href="https://colab.research.google.com/github/jongrantwritescode/low-code-ai/blob/main/Chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import pandas as pd

# %%
url = 'https://data.cdc.gov/resource/i2vk-mgdh.csv'
heart_df = pd.read_csv(url, index_col=0)

# %% [markdown]
# heart_df.head()

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2014 to 2014
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   locationabbr                1000 non-null   object
#  1   locationdesc                1000 non-null   object
#  2   geographiclevel             1000 non-null   object
#  3   datasource                  1000 non-null   object
#  4   class                       1000 non-null   object
#  5   topic                       1000 non-null   object
#  6   data_value                  758 non-null    float64
#  7   data_value_unit             1000 non-null   object
#  8   data_value_type             1000 non-null   object
#  9   data_value_footnote_symbol  242 non-null    object
#  10  data_value_footnote         242 non-null    object
#  11  stratificationcategory1     1000 non-null   object
#  12  stratification1             1000 non-null   object
# ...

# %%
heart_df = pd.read_csv('/content/heart.csv', engine='python')

import seaborn as sns
sns.violinplot(x='Data_Value', y='Stratification2', data=heart_df)
sns.displot(heart_df['Data_Valuet'])
